# %% [markdown]
# <a href="https://colab.research.google.com/github/abinaya-p/DataScience/blob/main/brain_tumor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# brain

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets

# %%
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings
for dirname,_, filenames in os.walk('/content/drive/MyDrive/brain'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(125).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(126).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(127).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(113).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(12).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(30).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(18).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(33).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(24).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(11).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(107).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(120).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(31).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(2).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(21).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(14).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(19).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(34).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(112).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(27).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(17).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(118).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(123).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(25).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(100).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(109).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(22).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(106).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(124).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(13).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(121).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(16).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(35).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(20).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(32).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(29).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(23).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(10).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(1).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(26).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(3).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(15).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(28).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(102).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(93).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(94).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(74).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(92).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(8).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(87).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(54).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(73).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(85).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(70).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(55).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(82).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(77).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(96).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(60).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(44).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(83).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(38).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image.jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(52).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(50).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(48).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(99).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(91).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(71).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(5).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(7).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(76).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(46).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(58).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(72).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(39).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(98).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(86).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(81).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(90).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(95).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(45).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(61).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(67).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(78).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(80).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(37).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(63).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(40).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(56).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(53).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(49).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(4).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(47).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(59).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(88).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(89).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(69).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(97).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(84).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(43).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(75).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(68).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(36).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(65).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(62).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(51).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(9).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(66).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(64).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(57).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(41).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(79).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(42).jpg
# /content/drive/MyDrive/brain/Testing/meningioma_tumor/image(6).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(17).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(10).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(12).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(16).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(15).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(2).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(18).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(19).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(13).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(11).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(1).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(14).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(100).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(40).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(59).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(99).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(37).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(60).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(92).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(90).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(97).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(91).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(42).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(51).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(89).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(64).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(86).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(79).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(49).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(38).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(5).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(41).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(44).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(93).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(58).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(46).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(68).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(67).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(74).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(43).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(61).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(28).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(3).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(52).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(23).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(87).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(98).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(31).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(69).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(95).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(83).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(24).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(77).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(7).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(56).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(80).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(76).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(6).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(81).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(54).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(21).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(78).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(32).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(48).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(29).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(84).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(85).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(63).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(34).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(20).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(73).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(33).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image.jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(65).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(36).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(30).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(55).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(57).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(9).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(62).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(71).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(8).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(25).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(82).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(22).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(70).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(88).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(35).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(39).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(45).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(50).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(4).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(47).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(26).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(53).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(27).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(72).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(66).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(94).jpg
# /content/drive/MyDrive/brain/Testing/glioma_tumor/image(75).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(11).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(98).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(35).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(38).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(13).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(83).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(71).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(74).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(26).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image.jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(2).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(12).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(48).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(93).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(66).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(78).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(59).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(94).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(97).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(77).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(56).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(36).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(18).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(32).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(1).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(62).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(3).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(100).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(53).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(88).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(22).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(14).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(33).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(50).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(49).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(61).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(23).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(67).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(58).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(57).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(103).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(28).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(101).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(30).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(87).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(19).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(76).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(46).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(68).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(29).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(81).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(99).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(15).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(4).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(40).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(85).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(34).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(54).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(75).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(69).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(52).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(90).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(41).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(91).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(92).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(7).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(63).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(60).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(27).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(44).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(79).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(102).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(17).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(42).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(21).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(31).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(104).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(65).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(47).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(72).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(43).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(82).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(8).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(51).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(5).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(20).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(39).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(73).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(55).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(10).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(80).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(9).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(16).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(37).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(70).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(89).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(95).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(86).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(25).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(64).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(24).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(6).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(84).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(96).jpg
# /content/drive/MyDrive/brain/Testing/no_tumor/image(45).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(68).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(87).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(98).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(94).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(3).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(45).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(95).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(48).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(64).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(28).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(78).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(60).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(1).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(6).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(38).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(19).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(85).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image.jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(63).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(81).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(35).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(52).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(31).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(51).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(66).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(37).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(56).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(67).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(41).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(7).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(18).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(61).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(46).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(73).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(88).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(89).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(82).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(93).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(5).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(42).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(65).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(15).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(54).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(70).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(21).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(97).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(36).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(23).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(13).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(86).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(55).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(11).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(53).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(44).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(47).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(30).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(43).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(79).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(90).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(20).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(91).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(96).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(10).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(8).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(27).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(22).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(57).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(77).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(92).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(69).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(2).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(76).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(34).jpg
# /content/drive/MyDrive/brain/Testing/pituitary_tumor/image(49).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(232).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(92).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(99).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(59).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(91).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(234).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(2).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (45).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(75).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (10).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(28).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(23).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(83).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(146).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(287).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (26).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(291).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(286).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (63).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (31).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(160).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(275).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(27).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(280).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(98).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (34).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(177).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(64).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(185).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (36).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(187).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(317).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(322).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(63).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(47).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(126).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(301).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(179).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(240).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(162).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(33).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(257).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(310).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(192).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (33).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (16).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(293).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(261).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(303).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (58).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/7.jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(25).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (39).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(86).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(42).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(32).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(202).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(16).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/8.jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(327).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(314).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(221).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (28).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(263).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(265).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(31).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(81).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(43).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (40).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (38).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(65).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/2.jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(254).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(233).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(255).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(41).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(169).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(55).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(161).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(119).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(295).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(135).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(60).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(219).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(195).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(151).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(171).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(299).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(199).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(194).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(48).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(271).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(211).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(117).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(96).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(297).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (61).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(14).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(21).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(34).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(235).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(165).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(267).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(288).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (55).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(45).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (46).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(269).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(311).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(190).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(163).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (21).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(89).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(138).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(110).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(222).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(136).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (35).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(274).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(167).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(318).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(53).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(93).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(71).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(152).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(100).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(316).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(68).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(66).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(251).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(87).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(307).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (8).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(141).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(198).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(296).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(159).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (11).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(244).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(154).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(61).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(180).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (52).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(183).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(127).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(156).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(123).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(106).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(158).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(278).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (18).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(3).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(82).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (23).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(143).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(324).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(85).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(253).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(67).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(188).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(84).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (42).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (15).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(24).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(283).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(108).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(197).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(69).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(186).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(11).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(115).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(181).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(308).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(50).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(105).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(70).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (5).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(72).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (60).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(95).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (51).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(259).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(212).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(201).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(217).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (62).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(220).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(17).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(285).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(39).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(116).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(147).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(170).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(282).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(313).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(22).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(262).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(241).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (24).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (44).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (53).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(294).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(128).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(131).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/6.jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(320).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(276).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (30).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(173).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (54).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (13).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(178).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(312).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(225).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(306).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(319).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(114).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(289).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(38).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(204).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(29).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(200).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (14).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (9).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(12).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(36).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(104).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (48).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(10).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(74).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(213).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(142).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(207).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(132).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(302).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(218).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(52).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(193).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(7).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(191).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (49).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(315).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(246).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(129).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(175).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(231).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/3.jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(120).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(209).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(90).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (64).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(326).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(155).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(46).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(112).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(149).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (50).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/5.jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(137).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image.jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(26).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(77).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (57).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(76).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(208).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(206).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(290).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(5).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(238).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(35).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (12).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(166).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(58).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(176).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (22).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(121).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(37).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (6).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (47).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(281).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (29).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(260).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (56).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(239).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(264).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(148).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (4).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(300).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(139).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(44).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(19).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(305).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (43).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(252).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(133).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(230).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(216).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(56).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(268).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(140).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(102).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(113).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(309).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(266).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(196).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (17).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(223).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(6).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(103).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(94).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(203).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(226).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (25).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(248).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(62).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (20).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (19).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(150).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(157).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/1.jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(40).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(107).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(144).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(184).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(224).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(122).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(272).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(210).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(18).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(174).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(172).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(277).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(242).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(304).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/4.jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(258).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(8).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(130).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(51).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (32).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(273).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (7).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(145).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(78).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(80).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(243).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(227).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(73).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(325).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image (41).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(168).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(88).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(292).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(125).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(279).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(182).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(284).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(118).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(15).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(164).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(236).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(57).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(298).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(249).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(321).jpg
# /content/drive/MyDrive/brain/Training/no_tumor/image(270).jpg
# ...
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (52).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (69).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (527).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (78).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (808).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (757).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (583).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (707).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (685).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (659).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (57).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (653).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (587).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (64).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (823).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (539).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (683).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (593).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (555).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (81).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (582).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (620).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (5).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (608).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (671).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (523).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (702).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (566).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (589).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (543).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (546).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (731).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (771).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (94).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (632).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (797).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (621).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (507).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (780).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (83).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (581).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (638).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (806).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (692).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (716).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (646).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (815).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (658).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (544).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (647).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (528).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (733).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (672).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (628).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (579).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (536).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (669).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (565).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (509).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (598).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (573).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (60).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (516).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (722).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (561).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (715).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (772).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (61).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (575).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (624).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (524).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (728).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (673).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (651).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (820).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (741).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (532).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (58).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (747).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (585).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (79).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (768).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (679).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (557).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (778).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (597).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (600).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (86).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (697).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (794).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (92).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (610).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (66).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (749).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (497).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (596).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (531).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (548).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (649).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (626).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (535).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (521).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (787).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (650).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (505).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (666).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (526).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (663).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (760).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (777).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (514).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (788).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (639).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (602).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (654).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (791).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (506).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (790).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (510).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (619).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (607).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (612).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (756).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (68).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (601).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (779).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (595).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (805).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (74).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (732).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (560).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (793).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (513).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (689).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (816).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (761).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (642).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (801).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (562).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (710).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (76).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (693).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (675).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (549).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (552).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (680).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (635).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (551).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (667).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (775).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (755).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (813).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (814).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (738).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (6).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (540).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (571).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (508).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (625).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (637).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (538).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (681).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (537).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (699).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (657).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (498).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (85).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (511).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (578).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (792).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (72).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (701).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (762).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (522).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (682).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (764).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (796).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (726).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (591).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (599).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (636).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (615).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (609).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (644).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (62).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (533).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (782).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (89).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (674).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (594).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (676).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (93).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (783).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (774).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (96).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (568).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (51).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (80).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (50).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (88).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (569).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (501).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (725).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (547).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (641).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (713).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (617).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (77).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (623).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (97).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (530).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (586).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (704).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (630).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (495).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (786).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (740).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (804).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (690).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (677).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (545).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (665).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (795).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (821).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (503).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (688).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (822).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (751).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (499).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (743).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (71).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (695).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (95).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (8).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (550).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (678).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (656).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (611).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (703).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (558).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (727).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (724).jpg
# /content/drive/MyDrive/brain/Training/pituitary_tumor/p (613).jpg

# %%
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

# %%
X_train = []
y_train = []
image_size = 150
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/brain','Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)

for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/brain','Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)

X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 849/849 [00:13<00:00, 62.68it/s]
# 100%|██████████| 395/395 [00:04<00:00, 85.25it/s]
# 100%|██████████| 822/822 [00:13<00:00, 62.57it/s]
# 100%|██████████| 837/837 [00:13<00:00, 61.98it/s]
# 100%|██████████| 100/100 [00:01<00:00, 80.73it/s]
# 100%|██████████| 105/105 [00:00<00:00, 115.99it/s]
# 100%|██████████| 115/115 [00:01<00:00, 75.25it/s]
# 100%|██████████| 74/74 [00:20<00:00,  3.56it/s]

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

# %%
X_train.shape
# Out:
# (3297, 150, 150, 3)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
effnet = EfficientNetB0(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step

# %%
model = effnet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=effnet.input, outputs = model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 150, 150, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 150, 150, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 150, 150, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 151, 151, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 75, 75, 32)           864       ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 75, 75, 32)           128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 75, 75, 32)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 75, 75, 32)           0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 32)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 75, 75, 16)           512       ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 75, 75, 16)           64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block2a_expand_conv (Conv2  (None, 75, 75, 96)           1536      ['block1a_project_bn[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 75, 75, 96)           384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 75, 75, 96)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 77, 77, 96)           0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 38, 38, 96)           864       ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 38, 38, 96)           384       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 38, 38, 96)           0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 96)                   0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 96)             0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 4)              388       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 96)             480       ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 38, 38, 96)           0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 38, 38, 24)           2304      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 38, 38, 24)           96        ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 38, 38, 144)          3456      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 38, 38, 144)          576       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 38, 38, 144)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 38, 38, 144)          1296      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 38, 38, 144)          576       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 38, 38, 144)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 144)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 38, 38, 144)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 38, 38, 24)           3456      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 38, 38, 24)           96        ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 38, 38, 24)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 38, 38, 24)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 38, 38, 144)          3456      ['block2b_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 38, 38, 144)          576       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 38, 38, 144)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 41, 41, 144)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 19, 19, 144)          3600      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 19, 19, 144)          576       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 19, 19, 144)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 144)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 19, 19, 144)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 19, 19, 40)           5760      ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 19, 19, 40)           160       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 19, 19, 240)          9600      ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 19, 19, 240)          960       ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 19, 19, 240)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 19, 19, 240)          6000      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 19, 19, 240)          960       ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 19, 19, 240)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 240)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 19, 19, 240)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 19, 19, 40)           9600      ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 19, 19, 40)           160       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 19, 19, 40)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 19, 19, 40)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 19, 19, 240)          9600      ['block3b_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 19, 19, 240)          960       ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 19, 19, 240)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv_pad (ZeroPa  (None, 21, 21, 240)          0         ['block4a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block4a_dwconv (DepthwiseC  (None, 10, 10, 240)          2160      ['block4a_dwconv_pad[0][0]']
#  onv2D)
#
#  block4a_bn (BatchNormaliza  (None, 10, 10, 240)          960       ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 10, 10, 240)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 240)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 10, 10, 240)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 10, 10, 80)           19200     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 10, 10, 80)           320       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 10, 10, 480)          38400     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 10, 10, 480)          1920      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 10, 10, 480)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, 10, 10, 480)          4320      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, 10, 10, 480)          1920      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 10, 10, 480)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 480)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 10, 10, 480)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 10, 10, 80)           38400     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 10, 10, 80)           320       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 10, 10, 80)           0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 10, 10, 80)           0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 10, 10, 480)          38400     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 10, 10, 480)          1920      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 10, 10, 480)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv (DepthwiseC  (None, 10, 10, 480)          4320      ['block4c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4c_bn (BatchNormaliza  (None, 10, 10, 480)          1920      ['block4c_dwconv[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 10, 10, 480)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 480)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 10, 10, 480)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 10, 10, 80)           38400     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 10, 10, 80)           320       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 10, 10, 80)           0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 10, 10, 80)           0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 10, 10, 480)          38400     ['block4c_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 10, 10, 480)          1920      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 10, 10, 480)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv (DepthwiseC  (None, 10, 10, 480)          12000     ['block5a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5a_bn (BatchNormaliza  (None, 10, 10, 480)          1920      ['block5a_dwconv[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 10, 10, 480)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 480)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 10, 10, 480)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 10, 10, 112)          53760     ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 10, 10, 112)          448       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 10, 10, 672)          75264     ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 10, 10, 672)          2688      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 10, 10, 672)          0         ['block5b_expand_bn[0][0]']
#  (Activation)
#
#  block5b_dwconv (DepthwiseC  (None, 10, 10, 672)          16800     ['block5b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5b_bn (BatchNormaliza  (None, 10, 10, 672)          2688      ['block5b_dwconv[0][0]']
#  tion)
#
#  block5b_activation (Activa  (None, 10, 10, 672)          0         ['block5b_bn[0][0]']
#  tion)
#
#  block5b_se_squeeze (Global  (None, 672)                  0         ['block5b_activation[0][0]']
#  AveragePooling2D)
#
#  block5b_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5b_se_squeeze[0][0]']
#  e)
#
#  block5b_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multipl  (None, 10, 10, 672)          0         ['block5b_activation[0][0]',
#  y)                                                                  'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv  (None, 10, 10, 112)          75264     ['block5b_se_excite[0][0]']
#  2D)
#
#  block5b_project_bn (BatchN  (None, 10, 10, 112)          448       ['block5b_project_conv[0][0]']
#  ormalization)
#
#  block5b_drop (Dropout)      (None, 10, 10, 112)          0         ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)           (None, 10, 10, 112)          0         ['block5b_drop[0][0]',
#                                                                      'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2  (None, 10, 10, 672)          75264     ['block5b_add[0][0]']
#  D)
#
#  block5c_expand_bn (BatchNo  (None, 10, 10, 672)          2688      ['block5c_expand_conv[0][0]']
#  rmalization)
#
#  block5c_expand_activation   (None, 10, 10, 672)          0         ['block5c_expand_bn[0][0]']
#  (Activation)
#
#  block5c_dwconv (DepthwiseC  (None, 10, 10, 672)          16800     ['block5c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5c_bn (BatchNormaliza  (None, 10, 10, 672)          2688      ['block5c_dwconv[0][0]']
#  tion)
#
#  block5c_activation (Activa  (None, 10, 10, 672)          0         ['block5c_bn[0][0]']
#  tion)
#
#  block5c_se_squeeze (Global  (None, 672)                  0         ['block5c_activation[0][0]']
#  AveragePooling2D)
#
#  block5c_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5c_se_squeeze[0][0]']
#  e)
#
#  block5c_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multipl  (None, 10, 10, 672)          0         ['block5c_activation[0][0]',
#  y)                                                                  'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv  (None, 10, 10, 112)          75264     ['block5c_se_excite[0][0]']
#  2D)
#
#  block5c_project_bn (BatchN  (None, 10, 10, 112)          448       ['block5c_project_conv[0][0]']
#  ormalization)
#
#  block5c_drop (Dropout)      (None, 10, 10, 112)          0         ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)           (None, 10, 10, 112)          0         ['block5c_drop[0][0]',
#                                                                      'block5b_add[0][0]']
#
#  block6a_expand_conv (Conv2  (None, 10, 10, 672)          75264     ['block5c_add[0][0]']
#  D)
#
#  block6a_expand_bn (BatchNo  (None, 10, 10, 672)          2688      ['block6a_expand_conv[0][0]']
#  rmalization)
#
#  block6a_expand_activation   (None, 10, 10, 672)          0         ['block6a_expand_bn[0][0]']
#  (Activation)
#
#  block6a_dwconv_pad (ZeroPa  (None, 13, 13, 672)          0         ['block6a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block6a_dwconv (DepthwiseC  (None, 5, 5, 672)            16800     ['block6a_dwconv_pad[0][0]']
#  onv2D)
#
#  block6a_bn (BatchNormaliza  (None, 5, 5, 672)            2688      ['block6a_dwconv[0][0]']
#  tion)
#
#  block6a_activation (Activa  (None, 5, 5, 672)            0         ['block6a_bn[0][0]']
#  tion)
#
#  block6a_se_squeeze (Global  (None, 672)                  0         ['block6a_activation[0][0]']
#  AveragePooling2D)
#
# ...
#  block6b_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6b_se_squeeze[0][0]']
#  e)
#
#  block6b_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6b_se_reshape[0][0]']
#
#  block6b_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6b_se_reduce[0][0]']
#
#  block6b_se_excite (Multipl  (None, 5, 5, 1152)           0         ['block6b_activation[0][0]',
#  y)                                                                  'block6b_se_expand[0][0]']
#
#  block6b_project_conv (Conv  (None, 5, 5, 192)            221184    ['block6b_se_excite[0][0]']
#  2D)
#
#  block6b_project_bn (BatchN  (None, 5, 5, 192)            768       ['block6b_project_conv[0][0]']
#  ormalization)
#
#  block6b_drop (Dropout)      (None, 5, 5, 192)            0         ['block6b_project_bn[0][0]']
#
#  block6b_add (Add)           (None, 5, 5, 192)            0         ['block6b_drop[0][0]',
#                                                                      'block6a_project_bn[0][0]']
#
#  block6c_expand_conv (Conv2  (None, 5, 5, 1152)           221184    ['block6b_add[0][0]']
#  D)
#
#  block6c_expand_bn (BatchNo  (None, 5, 5, 1152)           4608      ['block6c_expand_conv[0][0]']
#  rmalization)
#
#  block6c_expand_activation   (None, 5, 5, 1152)           0         ['block6c_expand_bn[0][0]']
#  (Activation)
#
#  block6c_dwconv (DepthwiseC  (None, 5, 5, 1152)           28800     ['block6c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6c_bn (BatchNormaliza  (None, 5, 5, 1152)           4608      ['block6c_dwconv[0][0]']
#  tion)
#
#  block6c_activation (Activa  (None, 5, 5, 1152)           0         ['block6c_bn[0][0]']
#  tion)
#
#  block6c_se_squeeze (Global  (None, 1152)                 0         ['block6c_activation[0][0]']
#  AveragePooling2D)
#
#  block6c_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6c_se_squeeze[0][0]']
#  e)
#
#  block6c_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6c_se_reshape[0][0]']
#
#  block6c_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6c_se_reduce[0][0]']
#
#  block6c_se_excite (Multipl  (None, 5, 5, 1152)           0         ['block6c_activation[0][0]',
#  y)                                                                  'block6c_se_expand[0][0]']
#
#  block6c_project_conv (Conv  (None, 5, 5, 192)            221184    ['block6c_se_excite[0][0]']
#  2D)
#
#  block6c_project_bn (BatchN  (None, 5, 5, 192)            768       ['block6c_project_conv[0][0]']
#  ormalization)
#
#  block6c_drop (Dropout)      (None, 5, 5, 192)            0         ['block6c_project_bn[0][0]']
#
#  block6c_add (Add)           (None, 5, 5, 192)            0         ['block6c_drop[0][0]',
#                                                                      'block6b_add[0][0]']
#
#  block6d_expand_conv (Conv2  (None, 5, 5, 1152)           221184    ['block6c_add[0][0]']
#  D)
#
#  block6d_expand_bn (BatchNo  (None, 5, 5, 1152)           4608      ['block6d_expand_conv[0][0]']
#  rmalization)
#
#  block6d_expand_activation   (None, 5, 5, 1152)           0         ['block6d_expand_bn[0][0]']
#  (Activation)
#
#  block6d_dwconv (DepthwiseC  (None, 5, 5, 1152)           28800     ['block6d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6d_bn (BatchNormaliza  (None, 5, 5, 1152)           4608      ['block6d_dwconv[0][0]']
#  tion)
#
#  block6d_activation (Activa  (None, 5, 5, 1152)           0         ['block6d_bn[0][0]']
#  tion)
#
#  block6d_se_squeeze (Global  (None, 1152)                 0         ['block6d_activation[0][0]']
#  AveragePooling2D)
#
#  block6d_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6d_se_squeeze[0][0]']
#  e)
#
#  block6d_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multipl  (None, 5, 5, 1152)           0         ['block6d_activation[0][0]',
#  y)                                                                  'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv  (None, 5, 5, 192)            221184    ['block6d_se_excite[0][0]']
#  2D)
#
#  block6d_project_bn (BatchN  (None, 5, 5, 192)            768       ['block6d_project_conv[0][0]']
#  ormalization)
#
#  block6d_drop (Dropout)      (None, 5, 5, 192)            0         ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)           (None, 5, 5, 192)            0         ['block6d_drop[0][0]',
#                                                                      'block6c_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 5, 5, 1152)           221184    ['block6d_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 5, 5, 1152)           4608      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 5, 5, 1152)           0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 5, 5, 1152)           10368     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 5, 5, 1152)           4608      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 5, 5, 1152)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1152)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 5, 5, 1152)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 5, 5, 320)            368640    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 5, 5, 320)            1280      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  top_conv (Conv2D)           (None, 5, 5, 1280)           409600    ['block7a_project_bn[0][0]']
#
#  top_bn (BatchNormalization  (None, 5, 5, 1280)           5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 5, 5, 1280)           0         ['top_bn[0][0]']
#  )
#
#  global_average_pooling2d (  (None, 1280)                 0         ['top_activation[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 4)                    5124      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 4054695 (15.47 MB)
# Trainable params: 4012672 (15.31 MB)
# Non-trainable params: 42023 (164.16 KB)
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("effnet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =12, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/12
# 84/84 [==============================] - ETA: 0s - loss: 0.4774 - accuracy: 0.8255
# Epoch 1: val_accuracy improved from -inf to 0.90236, saving model to effnet.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 84/84 [==============================] - 66s 187ms/step - loss: 0.4774 - accuracy: 0.8255 - val_loss: 0.2752 - val_accuracy: 0.9024 - lr: 0.0010
# Epoch 2/12
# 84/84 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9307
# Epoch 2: val_accuracy improved from 0.90236 to 0.93266, saving model to effnet.h5
# 84/84 [==============================] - 11s 136ms/step - loss: 0.1987 - accuracy: 0.9307 - val_loss: 0.2292 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 3/12
# 84/84 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9667
# Epoch 3: val_accuracy did not improve from 0.93266
# 84/84 [==============================] - 11s 130ms/step - loss: 0.0942 - accuracy: 0.9667 - val_loss: 0.3645 - val_accuracy: 0.9024 - lr: 0.0010
# Epoch 4/12
# 84/84 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9723
# Epoch 4: val_accuracy did not improve from 0.93266
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 84/84 [==============================] - 11s 130ms/step - loss: 0.0828 - accuracy: 0.9723 - val_loss: 0.2452 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 5/12
# 84/84 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9835
# Epoch 5: val_accuracy improved from 0.93266 to 0.94949, saving model to effnet.h5
# 84/84 [==============================] - 12s 138ms/step - loss: 0.0465 - accuracy: 0.9835 - val_loss: 0.1399 - val_accuracy: 0.9495 - lr: 3.0000e-04
# Epoch 6/12
# 84/84 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9925
# Epoch 6: val_accuracy improved from 0.94949 to 0.95960, saving model to effnet.h5
# 84/84 [==============================] - 12s 143ms/step - loss: 0.0230 - accuracy: 0.9925 - val_loss: 0.0939 - val_accuracy: 0.9596 - lr: 3.0000e-04
# Epoch 7/12
# 84/84 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9966
# Epoch 7: val_accuracy improved from 0.95960 to 0.96970, saving model to effnet.h5
# 84/84 [==============================] - 12s 144ms/step - loss: 0.0137 - accuracy: 0.9966 - val_loss: 0.0776 - val_accuracy: 0.9697 - lr: 3.0000e-04
# Epoch 8/12
# 84/84 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9970
# Epoch 8: val_accuracy did not improve from 0.96970
# 84/84 [==============================] - 11s 130ms/step - loss: 0.0131 - accuracy: 0.9970 - val_loss: 0.1111 - val_accuracy: 0.9697 - lr: 3.0000e-04
# Epoch 9/12
# 84/84 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9970
# Epoch 9: val_accuracy did not improve from 0.96970
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 84/84 [==============================] - 11s 131ms/step - loss: 0.0120 - accuracy: 0.9970 - val_loss: 0.0880 - val_accuracy: 0.9697 - lr: 3.0000e-04
# Epoch 10/12
# 84/84 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9978
# Epoch 10: val_accuracy improved from 0.96970 to 0.97306, saving model to effnet.h5
# 84/84 [==============================] - 12s 140ms/step - loss: 0.0091 - accuracy: 0.9978 - val_loss: 0.0744 - val_accuracy: 0.9731 - lr: 9.0000e-05
# Epoch 11/12
# 84/84 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9959
# Epoch 11: val_accuracy did not improve from 0.97306
# 84/84 [==============================] - 11s 132ms/step - loss: 0.0131 - accuracy: 0.9959 - val_loss: 0.0622 - val_accuracy: 0.9731 - lr: 9.0000e-05
# Epoch 12/12
# 84/84 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9974
# Epoch 12: val_accuracy improved from 0.97306 to 0.97643, saving model to effnet.h5
# 84/84 [==============================] - 12s 140ms/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0710 - val_accuracy: 0.9764 - lr: 9.0000e-05

# %%
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_red = ["#331313", "#582626", '#9E1717', '#D35151', '#E9B4B4']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']

# %%
filterwarnings('ignore')

epochs = [i for i in range(12)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label ='Training Loss')
ax[1].plot(epochs, val_loss, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 11/11 [==============================] - 3s 89ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       104
#            1       0.98      1.00      0.99        41
#            2       0.97      0.98      0.97        97
#            3       0.98      1.00      0.99        88
#
#     accuracy                           0.98       330
#    macro avg       0.98      0.99      0.98       330
# weighted avg       0.98      0.98      0.98       330

# %%
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True,
           cmap=colors_green[::-1],alpha=0.7,linewidths=2,linecolor=colors_dark[3])
fig.text(s='Heatmap of the Confusion Matrix',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=0.92,x=0.28,alpha=0.8)

plt.show()

# %%
def img_pred(upload):
    for name, file_info in uploader.value.items():
        img = Image.open(io.BytesIO(file_info['content']))





    opencvImage = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
    img = cv2.resize(opencvImage,(150,150))
    img = img.reshape(1,150,150,3)
    p = model.predict(img)
    p = np.argmax(p,axis=1)[0]

    if p==0:
        p='Glioma Tumor'
    elif p==1:
        print('The model predicts that there is no tumor')
    elif p==2:
        p='Meningioma Tumor'
    else:
        p='Pituitary Tumor'

    if p!=1:
        print(f'The Model predicts that it is a {p}')

# %%
uploader = widgets.FileUpload()
display(uploader)
# Out:
# FileUpload(value={}, description='Upload')

# %%
button = widgets.Button(description='Predict')
out = widgets.Output()
def on_button_clicked(_):
    with out:
        clear_output()
        try:
            img_pred(uploader)

        except:
            print('No Image Uploaded/Invalid Image File')
button.on_click(on_button_clicked)
widgets.VBox([button,out])
# Out:
# VBox(children=(Button(description='Predict', style=ButtonStyle()), Output()))
